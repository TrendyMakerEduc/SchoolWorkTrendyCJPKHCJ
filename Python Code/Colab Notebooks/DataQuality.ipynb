# %%
#DATA QUALITY
#Poor data quality negatively affects many data processing efforts
#Data mining example: a classification model for detecting people who are loan risks is built using poor data
#-Some credit-worthy candidates are denied loans
#-More loans are given to individuals that default
#What kinds of data quality problems?
#How can we detect these problems?
#What can we do about these problems

#Examples of data quality problems:
#- Noise and outliers( if we accept the outliers as regular data, it will be poor data)
#- Wrong data (feet and inches)
#- Fake data (just made up)
#- Missing values (missing variables, multiple sources, attributes not defined)
#- Duplicate data (2 rows that are the exact same value)

#Noise
#- For objects, noise is an extraneous object
#- For attributes, noise refers to modification of orginal values
#   - Examples: distortion of a person's voice when talking on a poor phone and "snow" on televeision screens

#Outliers
#Outliers are data objects with characteristics that are considerably different than most of the other data objects in the data set
#Case 1: Outliers are noise that interferes with data analysis
#Case 2: Outliers are the goal of our analysis
#Causes? human error, incorrect values, different cluster points

#Missing values
#Reasons for missing values
#Information is not collected
#Attributes may not be applicable to all cases
#-E.g. annual income is not applicable to children
#Handling missing values- null values
#-Eliminate data objects or variables
#-Estimate missing values
#-Ignore the missing value during analysis

#Duplicated data
#-Data set may include data objects that are duplicates, or almost suplicates of 
#one another
#-Major issue when merging data from heterogeneous sources
#Examples:
#-Same person with mulitple email addresses
#Data Cleaning
#-Process of dealing with duplicate data issues
#When should duplicate data not be removed

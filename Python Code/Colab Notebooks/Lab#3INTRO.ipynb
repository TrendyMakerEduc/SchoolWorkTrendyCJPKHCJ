# %%
#LAB 3
#PRE EXERCISES

#1)Assume the days of the week are numbered 0,1,2,3,4,5,6 from Sunday to Saturday. 
#  Write a function which is given the day number, and it returns the day name (a string).

def Days_Of_Week(x):
  if(x == 0):
    return "Sunday"
  elif(x == 1):
    return "Monday"
  elif(x == 2):
    return "Tuesday"
  elif(x == 3):
    return "Wednesday"
  elif(x == 4):
    return "Thursday"
  elif(x == 5):
    return "Friday"
  elif(x == 6):
    return "Saturday"
  else:
    return

#2)You go on a wonderful holiday (perhaps to jail, if you don’t like happy exercises) leaving on day number 3 (a Wednesday). 
#You return home after 137 sleeps. Write a general version of the program which asks 
#for the starting day number, and the length of your stay, and it will tell you the name of day of the week you will return on.

def Calculate_Weekday():
  TotalSleeps = 137
  Divisor = 7
  DayStarted = 3
  DayOfWeek = TotalSleeps % Divisor
  return Days_Of_Week(DayStarted + (DayOfWeek-1))


#10)Write a function find_hypot which, given the length of two sides of a right-angled triangle,
#   returns the length of the hypotenuse. (Hint: x ** 0.5 will return the square root.)

def find_hypot(x,y):
  z = x **2 + y**2
  z = z **0.5
  return z

find_hypot(3,4)

#11)Write a function is_rightangled which, given the length of three sides of a triangle, will determine whether the triangle
# is right-angled. Assume that the third argument to the function is always the longest side. 
# It will return True if the triangle is right-angled, or False otherwise.

def is_rightangled(x,y,z):
  sqr = x**2 + y **2
  if((z**2) == sqr):
    return True
  else:
    return False

is_rightangled(5, 12, 13)

##BEFORE KATTIS
#1)Write a function did_pass(grade: float) -> bool: that returns True if the grade is 50 or above, and False otherwise
#Be sure to write some assert tests to verify correctness
def did_pass(grade: float) -> bool:
  if (grade >= 50):
    return True
  else:
    return False

#Be sure to write some assert tests to verify correctness

assert did_pass(99) == True
assert did_pass(9) == False
assert did_pass(50) == True

#2)Write some code to take input from the user and store the inputted value in a variable

varsity = float(input("What is the grade you are recieving?"))

#3) Call the function did_pass with the inputted value from the previous question as the argument for the function

print(did_pass(varsity))

#4) Write a function called letter_grade(percent_grade: float) -> str: 
#   that takes a grade as a percentage and returns the appropriate letter grade

def letter_grade(percent_grade: float) -> str:
  if(percent_grade <= 49):
    return "F"
  elif(percent_grade >= 50 and percent_grade <= 59):
    return "D"
  elif(percent_grade >= 60 and percent_grade <= 69):
    return "C"
  elif(percent_grade >= 70 and percent_grade <= 79):
    return "B"
  elif(percent_grade >= 80 and percent_grade <= 89):
    return "A"
  elif(percent_grade >= 90 and percent_grade <= 100):
    return "A+"
  else:
    return

#Write assert tests to verify correctness
assert letter_grade(50) == "D"
assert letter_grade(60) == "C"
assert letter_grade(100) == "A+"

#4) Rewrite letter_grade(percent_grade: float) -> str: such that you reverse the order you check the grade in

def letter_grade2(percent_grade: float) -> str:
  if(percent_grade >= 90 and percent_grade <= 100):
    return "A+"
  elif(percent_grade >= 80 and percent_grade <= 89):
    return "A"
  elif(percent_grade >= 70 and percent_grade <= 79):
    return "B"
  elif(percent_grade >= 60 and percent_grade <= 69):
    return "C"
  elif(percent_grade >= 50 and percent_grade <= 59):
    return "D"
  elif(percent_grade <= 49):
    return "F"
  else:
    return

#Run the assert tests from the previous question
assert letter_grade(50) == "D"
assert letter_grade(60) == "C"
assert letter_grade(100) == "A+"

#KATTIS PROBLEMS

#Quadrant Selection

def Define_Quadrant(x,y):
  if(x == 0 and y == 0):
    return "Quadrant 1", "Quadrant 2", "Quadrant 3", "Quadrant 4"
  elif(x > 0 and y == 0):
    return "Quadrant 1", "Quadrant 4"
  elif(x < 0 and y == 0):
    return "Quadrant 2", "Quadrant 3"
  elif(x == 0 and y > 0):
    return "Quadrant 1", "Quadrant 2"
  elif(x == 0 and y < 0):
    return "Quadrant 3", "Quadrant 4"
  elif(x > 0 and y > 0):
    return "Quadrant 1"
  elif(x < 0 and y > 0):
    return "Quadrant 2"
  elif(x < 0 and y < 0):
    return "Quadrant 3"
  elif(x > 0 and y < 0):
    return "Quadrant 4"
  else:
    return

Define_Quadrant(13, -13)

def Define_Quadrant():
  x = int(input())
  y = int(input())
  if(x > 0 and y > 0):
    return 1
  elif(x < 0 and y > 0):
    return 2
  elif(x < 0 and y < 0):
    return 3
  elif(x > 0 and y < 0):
    return 4
  else:
    return
    
print(Define_Quadrant())
# Out:
# What is the grade you are recieving?1
# False
# 1
# 1
# 1

# %%
def Define_Quadrant():
  x = int(input())
  y = int(input())
  if(x > 0 and y > 0):
    return 1
  elif(x < 0 and y > 0):
    return 2
  elif(x < 0 and y < 0):
    return 3
  elif(x > 0 and y < 0):
    return 4
  else:
    return
    
print(Define_Quadrant())
# Out:
# 1
# -4
# 4

# %%
def Judging_Moose():
  data = input()       # Read a WHOLE, SINGLE line of input
  data = data.split()  # Split string into individual pieces
  l = int(data[0]) # Take string from data[X], convert it to int...
  r = int(data[1]) # ... And store it in some variable 
  total = l + r
  if(l > r):
    total = l * 2
    return "Odd " + str(total)
  elif (r > l):
    total = r * 2
    return "Odd " + str(total)
  elif(r == 0 and l == 0):
    return "Not a moose"
  else:
    return "Even " + str(total)

print(Judging_Moose())
# Out:
# 13 13
# 'Even 26'

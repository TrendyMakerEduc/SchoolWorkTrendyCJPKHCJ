# %%
##New functions for lists
##This makes two lists
a = [0, 1, 2]
b = a[:] ##or a.copy

b = a ##This makes an aliases of a
##EXERCISE- aliases and copies
l = [1]
l_aliases = l #aliases
l_copy = l[:] #copy


##Adds to list in address in memory
def add_to_list(some_list, value):
  some_list.append(value)
  ##a common mistake is returning the list inside of the list, creating aliases, when you return, you must use the SAME list
  return some_list

my_list = ['a']
##You must reassign the variable when using the return function
my_list = add_to_list(my_list, 42)
print(my_list)
##A side effect of a function that you need to be careful of, and must keep list on the outside

# %%
def my_sum(list1, list2):
  ##Return 
  new_list = []
  count = 0
  while (count < len(list1 + list2)):
    sum += (list1[count] + list2[count])
    new_list.append(sum)
  if(count == len(list1 + list2)):

    return new_list

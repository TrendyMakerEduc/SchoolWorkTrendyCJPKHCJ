# %%
##LAB 2 INTRO TO PROGRAMMING
#Excercise 2.14
#1)  Take the sentence: All work and no play makes Jack a dull boy. Store each word in a separate variable, 
#    then print out the sentence on one line using print.
a = "All"
b = "work"
c = "and"
d = "no"
e = "play"
f = "makes"
g = "Jack"
h = "a"
i = "dull"
j = "boy"
print(a + " " + b + " " + c + " " + d + " " + e + " " + f + " " + g + " " + h + " " + i + " " + j + "." )
# Out:
# All work and no play makes Jack a dull boy.

# %%
# 2) Add parenthesis to the expression 6 * 1 - 2 to change its value from 4 to -6.
a = 6 * (1 - 2)
print(a)
# Out:
# -6

# %%
# 3)Place a comment before a line of code that previously worked, and record what happens when you rerun the program.

# %%
# 4)Start the Python interpreter and enter bruce + 4 at the prompt. This will give you an error:
#NameError: name 'bruce' is not defined
#Assign a value to bruce so that bruce + 4 evaluates to 10.
bruce = 6
print(bruce + 4)
# Out:
# 10

# %%
# 5)The formula for computing the final amount if one is earning compound interest is given on Wikipedia as
# Write a Python program that assigns the principal amount of $10000 to variable P, assign to n the value 12, and assign to r the interest rate of 8%.
# Then have the program prompt the user for the number of years t that the money will be compounded for. Calculate and print the final amount after t years.
def Compound_Interest():
  P = 10000
  n = 12
  r = 0.08
  t = float(input("How many years will the interest be compounded for?: "))
  R = P * (1 + (r/n))**(n * t)
  return (R)

# %%
#6 Evaluate the following numerical expressions in your head, then use the Python interpreter to check your results:
#1
#5 % 2
#2
#9 % 5
#3
#15 % 12
#4
#12 % 15
#5
#6 % 6
#6
#0 % 7
#7 CANNOT BE DONE
#7 % 0
# Out:
# 1

# %%
#7 You look at the clock and it is exactly 2pm. You set an alarm to go off in 51 hours.
#At what time does the alarm go off? (Hint: you could count on your fingers,
#but this is not what we’re after. If you are tempted to count on your fingers, change the 51 to 5100.)

hours_in_day = 24
current_time = 2
Z = current_time + 51
current_time = Z % hours_in_day
Z = current_time
print(Z)
# Out:
# 5

# %%
#8 Write a Python program to solve the general version of the above problem. Ask the user for the time now (in hours), and ask for the
# number of hours to wait. Your program should output what the time will be on the clock when the alarm goes off.

##ANSWER IS ABOVE, DID NOT READ LAB AND DID THEM ALL

# %%
#Chapter 4 Exercise
#8) Write a function area_of_circle(r) which returns the area of a circle of radius r.

def area_of_circle(r):
  PIE = 3.141592653589793
  AREA = PIE * r ** 2
  return AREA
area_of_circle(10)
# Out:
# 314.1592653589793

# %%
#Before Kattis
#Write a function called add_five_print(some_integer)

def add_five_print(some_integer):
  #Adding 5
  a = some_integer + 5
  print(a)
add_five_print(6)
add_five_print(7)
add_five_print(10)
# Out:
# 11
# 12
# 15

# %%
# 2) Write a function called 
#add_two_numbers_print(some_integer, some_other_integer))
def add_two_numbers_print(some_integer, some_other_integer):
  result = some_integer + some_other_integer
  print(result)

add_five_print(5, 6)
add_five_print(10, 20)
add_five_print(30, 90)
# Out:
# 11
# 30
# 120

# %%
# 3) Write a function called
#add_two_numbers_return(some_integer, some_other_integer)

def add_two_numbers_return(some_integer, some_other_integer):
  result = some_integer + some_other_integer
  return result

add_two_numbers_return(6, 10)
add_two_numbers_return(40, 100)
add_two_numbers_return(100, 1000)
##RETURNS LAST ONE CALLED
# Out:
# 1100

# %%
#4 Run the following code and take note of the output

result = add_two_numbers_return(4, 5)
print(result)
# Out:
# 9

# %%
#5 Run the following code and take note of the output

result = add_two_numbers_print(4, 5)
print(result)

## 6) THEY BEHAVE DIFFERENTLY DUE TO THE PRINT NOT STORING
## THE VALUE, DUE TO PRINT JUST PRINTING, while RETURN
## GIVES THE VALUE TO USE AT THE END OF THE EQUATION
## PRINT IS CALLED TWICE IN THIS MANNER, SO THE RESULT HAS
## ALREADY BEEN USED
# Out:
# 9
# None

# %%
#7 Write a function called this_is_tough(n1, n2, n3, n4)

def this_is_tough(n1, n2, n3, n4):
  result1 = add_two_numbers_return(n1, n2)
  result2 = add_two_numbers_return(result1, n3)
  result3 = add_two_numbers_return(result2, n4)
  return result3

this_is_tough(1,2,3,4)
this_is_tough(3,6,9,12)
# Out:
# 30

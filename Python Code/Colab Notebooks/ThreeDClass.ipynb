# %%
class Object:
  def __init__(self, radius, volume, degrees, pi, diamter  a, b, c, d, e, f, g, h, sum, interiorangle, vertex, circum, point, top, base, slope,  length, width, height, ):
    self.radius = radius
    self.volume = volume
    self.degrees = degrees
    self.diamter = diameter
    self.a = a
    self.b = b
    self.c = c
    self.d = d
    self.e = e
    self.f = f
    self.g = g
    self.h = h
    self.sum = sum
    self.interiorangle = interiorangle
    self.vertex = vertex
    self.circum = circum
    self.point = point
    self.top = top
    self.base = base
    self.slope = slope
    self.length = length
    self.width = width
    self.height = height
    pi = 3.14159265359
  def CalcSphereArea(self, radius):

    return SphereArea
  def Sin(angle, length, height):

  def RadiusCylinder(self, a, b):
    self.a = a
    self.b = b
    if (a > 0 and b < 0):
      self.radius = (a + b) / 2
      return self.radius
    elif (a < 0 and b > 0):
      self.radius = (a - b) / 2
      return self.radius
    elif (a > 0 and b > 0):
      if (b > a):
        self.radius = (b - a) / 2
        return self.radius
      else:
        self.radius = (a - b) / 2
        return self.radius
    elif (a < 0 and b < 0):
        self.radius = (-(b + a)) / 2
        return self.radius

    def DiameterCylinder(self):
      self.a = a
      self.b = b
      if (a > 0 and b < 0):
        self.circum = (a + b)
        return self.circum
      elif (a < 0 and b > 0):
       self.circum = (a - b)
       return self.circum
      elif (a > 0 and b > 0):
       if (b > a):
        self.circum = (b - a)
        return self.circum
       else:
        self.circum = (a - b)
        return self.circum
      elif (a < 0 and b < 0):
        self.circum = (-(b + a))
        return self.circum

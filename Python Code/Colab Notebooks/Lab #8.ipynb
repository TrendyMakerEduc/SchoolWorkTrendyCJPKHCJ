# %%
## Original List
a = [0, 0, 0]
## Problem 1- Adding variables for use in splicing/splitting
c = [0, 0, 0]
d = [0, 0, 0]
## 3 Aliases assigned to b list
b = [a,a,a]
## Problem 1- Reassigning the b list to take multiple variables that are different
b = [a, c, d]

## For Testing
## Problem 1- Getting past aliases
b[1][1] = 1
# Problem 1.5- Using a different number and assigning it to list b
b[0][1] = 1


## For each row in the new variable b
for row in b:
  ## Print variable = string
    toPrint = ''
    ## for the new variable d in row
    for d in row:
      ## increment new strings using d in row to print in the string
        toPrint += str(d) + ' '

    print(toPrint)



# Problem 3- Using nums to add list integers to a target
def NumberAddition(num1, num2):

  nums = [2, 7, 11, 15, 17, 21, 23, 25, 26, 27, 28]
  try:
      Target = nums[num1] + nums[num2]
      return Target
  except IndexError:
      print("List index is out of range! Pick a lower index number.")
  

def CheckListForTarget(nums, target):
  a = 0
  b = 1
  for target in range(len(nums)):
    if target != (nums[a] + nums[b]):
      b += 1
      if b > (nums[b])
# Out:
# 0 1 0
# 0 1 0
# 0 0 0
# 35

# %%
# Kattis Problem 1- Chessboard pieces

def Chessboard():
  ChessSet = input("Please put a space and input the amount you have in this order. King, Queen, Rooks, Bishops, Knights, Pawns :")
  ChessSetInput = ChessSet.split()
  for integer in range(0, len(ChessSet)):
    ChessSet[integer] = int(ChessSet[integer])
    if(ChessSet[0] != 2 and ChessSet[0] > 2):
      return -(ChessSet[0] - 2)
    else:
      return abs(ChessSet[0] - 2)
    if(ChessSet[1] != 2 and ChessSet[1] > 2):
      return -(ChessSet[1] - 2)
    else:
      return abs(ChessSet[1] - 2)
    if(ChessSet[2] != 4 and ChessSet[2] > 4):
      return -(ChessSet[0] - 4)
    else:
      return abs(ChessSet[0] - 4)
    if(ChessSet[3] != 4 and ChessSet[3] < 4):
      return -(ChessSet[3] - 4)
    else:
      return abs(ChessSet[3] - 4)
    if(ChessSet[4] != 4 and ChessSet[4] < 4):
      return -(ChessSet[4] - 4)
    else:
      return abs(ChessSet[4] - 4)
    if(ChessSet[5] != 8 and ChessSet[5] < 8):
      return -(ChessSet[5] - 8)
    else:
      return abs(ChessSet[5] - 8)
    print(ChessSet[integer] + " ")
  
Chessboard()
# Out:
# Please put a space and input the amount you have in this order. King, Queen, Rooks, Bishops, Knights, Pawns :1 2 3 4 5 6
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-24-58dad67bdacd> in <module>()
#      32     print(ChessSet[integer] + " ")
#      33
# ---> 34 Chessboard()
#
# <ipython-input-24-58dad67bdacd> in Chessboard()
#       5   ChessSetInput = ChessSet.split()
#       6   for integer in range(0, len(ChessSet)):
# ----> 7     ChessSet[integer] = int(ChessSet[integer])
#       8     if(ChessSet[0] != 2 and ChessSet[0] > 2):
#       9       return -(ChessSet[0] - 2)
#
# TypeError: 'str' object does not support item assignment

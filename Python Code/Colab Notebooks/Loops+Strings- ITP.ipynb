# %%
## Counting all numbers from 0 to n
def int_sum(n):
  counter = 0
  sum = 0
  while(counter < n):
    counter += 1
    sum += counter
    print(str(sum))
  return sum


int_sum(10)

def sum_even_number(n: int) -> int:
  counter = 0
  sum = 0
  while(counter <= n):
    if(n % 2 == 0):
      sum += counter
      print(sum)
    counter += 1
    return sum

sum_even_number(10)

## Strings
# We can access these characters with the splicing method
a = "Hello World!"
a[0]

##Using this with input, we can create a formula to evaluate every character
def character_Iteration():
  character = input("What word are you searching?")
  n = 0
  #len is important to use
  while(n < len(character)):
    print(character[n])
    n += 1

character_Iteration()

##Using for loops, we may simplify, and make the word alot easier to grab, we may want to return
##

def vertical_print_for(a_string: str):
    """
    Print out a string vertically. In other words, print out a single character on each line.

    :param a_string: Some string to print out
    :type a_string String
    """
    for char in a_string:
        print(char)

#Returns true if substring is located in string, to incorporate excel reading, we need a while loop to iterate through all the elements
#in the array
def character_is_in(needle: str, haystack : str) -> bool:
  if(needle in haystack):
    return haystack
  else:
    return needle

##This is for finding singular character instances
def character_in_haystack(needle: str, haystack : str) -> bool:
  for char in haystack:
    if char == needle:
      return True
    else:
      continue
  return False
## Returns where the character is located
def character_is_at(needle: str, haystack: str) -> int:
  count = 0
  while count < len(haystack):
    if haystack[count] == needle:
      return count
    count = count + 1
  return -1
    

character_is_at("e", "Hello")


#It would be useful if the function returns true to return the full word
#We can do this from returned cells in excel files. (Great for data science)
# fanciness if divided into arrays to search the certain word through the arrays, to return that array position.



#We can incorporate special characters in strings, for example \n returns a new line, or \t is the tab key
string = "Hello\nWorld"

#To convert numbers to character, we use the ASC# table
#We will not use this though. But it is good for a fine line of security in the programming.

#Printing variables in a nice way is easy, we use f before the string, and put the variables in the curly quotes
name = "Danny"
course_code= "CSCI 161"
to_print = f"My name is {name} and I take {course_code}"
print(to_print)
# Out:
# 1
# 3
# 6
# 10
# 15
# 21
# 28
# 36
# 45
# 55
# 0
# What word are you searching?word
# w
# o
# r
# d
# My name is Danny and I take CSCI 161

# %%
## Increment, Decrement, Divide, and Multiply X, Y, and Z values manually


def IncrementXbyValue(x, x1):
  x = x + x1
  return x

def IncrementYbyValue(y, y1):
  y = y + y1
  return y

def IncrementZbyValue(z, z1):
  z = z + z1
  return z

def DecrementXbyValue(x, x1):
  x = x - x1
  return x

def DecrementYbyValue(y, y1):
  y = y - y1
  return y

def DecrementZbyValue(z, z1):
  z = z - z1
  return z

def DivideXbyValue(x, x1):
  x = x/x1
  return x

def DivideYbyValue(y, y1):
  y = y/y1
  return y

def DivideZbyValue(z, z1):
  z = z/z1
  return z

def MultiplyXbyValue(x, x1):
  x = x * x1
  return x

def MultiplyYbyValue(y, y1):
  y = y * y1
  return y

def MultiplyZbyValue(z, z1):
  z = z * z1
  return z







IncrementX(6,2)
# Out:
# 8

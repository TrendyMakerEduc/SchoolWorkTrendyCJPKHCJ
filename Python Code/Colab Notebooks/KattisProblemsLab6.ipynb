# %%
##PROBLEM 1

Name = input("What is the name of the people working, and seperate each by hyphen:  ")

def Name_Shorten():
    char = Name
    count = 0
    string = ""
    while(count < len(Name)):
      if(char[count].isupper()):
        string += char[count]
      count += 1
    print(string)
Name_Shorten()


##PROBLEM 2
# Out:
# What is the name of the people working, and seperate each by hyphen:  Ran-Run-Walk
# RRW

# %%
##PROBLEM 2
Name = input()

def Change_Apaxian_Scroll_Name(Name):
    count = 0
    while (count < len(Name)):
       if(Name[count] == Name[count - 1]):
          string = Name[count]
          Name = Name.replace(string ,"", 1)
          count = 0
          

     
       count += 1  
    return(Name)
Change_Apaxian_Scroll_Name(Name)
# Out:
# ooooooooooooooooooooobbbbbbbbbbbbbbbbbbbbbbbbbbbbaaaaaaaaaaaaaaaaaaaatttttttttttttttttttttttyyyyyyyyyyyyyyy
# 'obaty'
